# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url_2 = "https://www.shop.tatte.kz/blog/coffee-room/coffee-shop-target-audience.html"

response_2 = requests.get(url_2, headers=headers)

soup_2 = BeautifulSoup(response_2.text, 'html.parser')

table_2 = soup_2.find_all('table')[2]

rows = table_2.find_all('tr')

column_1 = []
column_2 = []
column_3 = []
column_4 = []
column_5 = []
column_6 = []
column_7 = []
column_8 = []

for row in rows:
    columns = row.find_all('td')
    print(columns)
    col1 = columns[0].get_text(strip=True)
    col2 = columns[1].get_text(strip=True)
    col3 = columns[2].get_text(strip=True)
    col4 = columns[3].text.strip()
    col5 = columns[4].text.strip()
    column_1.append(col1)
    column_2.append(col2)
    column_3.append(col3)
    column_4.append(col4)
    column_5.append(col5)

df = pd.DataFrame({
    column_1[0]: column_1[1:],
    column_2[0]: column_2[1:],
    column_3[0]: column_3[1:],
    column_4[0]: column_4[1:],
    column_5[0]: column_5[1:]
})

df

import pandas as pd
import plotly.express as px

df['Качественный кофе'] = df['Качественный кофе'].str.rstrip('%').astype(float)
df['Комфортное пространство для работы/отдыха'] = df['Комфортное пространство для работы/отдыха'].str.rstrip('%').astype(float)
df['Быстрое обслуживание'] = df['Быстрое обслуживание'].str.rstrip('%').astype(float)
df['Разнообразие меню'] = df['Разнообразие меню'].str.rstrip('%').astype(float)

categories = ['Качественный кофе', 'Комфортное пространство для работы/отдыха', 'Быстрое обслуживание', 'Разнообразие меню']
values = [df.loc[2, categories].tolist(), df.loc[6, categories].tolist(), df.loc[4, categories].tolist()]
audience = ['фрилансеры', 'местные жители', 'студенты']

for i in range(3):
    bar_data = pd.DataFrame({
        'Сегмент ЦА': categories,
        'Процент': values[i]
    })

    fig = px.bar(bar_data, x='Процент', y='Сегмент ЦА',
                  orientation='h',
                  title=f'Что больше всего ценят {audience[i]}',
                  color_discrete_sequence=px.colors.qualitative.Pastel)

    fig.update_layout(
          xaxis_title='Процент',
          yaxis_title=''
      )

    fig.show()
# Out:
# [<td><strong><meta charset="utf-8"/>Тип клиента </strong></td>, <td><strong><meta charset="utf-8"/>Качественный кофе </strong></td>, <td><strong><meta charset="utf-8"/>Комфортное пространство для работы/отдыха </strong></td>, <td><strong><meta charset="utf-8"/>Быстрое обслуживание </strong></td>, <td><strong><meta charset="utf-8"/>Разнообразие меню </strong></td>]
# [<td><meta charset="utf-8"/>Предприниматели</td>, <td><meta charset="utf-8"/>80%</td>, <td><meta charset="utf-8"/>70%</td>, <td><meta charset="utf-8"/>70%</td>, <td><meta charset="utf-8"/>50%</td>]
# [<td><meta charset="utf-8"/>Работники офисов</td>, <td><meta charset="utf-8"/>70%</td>, <td><meta charset="utf-8"/>40%</td>, <td><meta charset="utf-8"/>80%</td>, <td><meta charset="utf-8"/>30%</td>]
# [<td><meta charset="utf-8"/>Фрилансеры</td>, <td><meta charset="utf-8"/>70%</td>, <td><meta charset="utf-8"/>80%</td>, <td><meta charset="utf-8"/>40%</td>, <td><meta charset="utf-8"/>60%</td>]
# ...
